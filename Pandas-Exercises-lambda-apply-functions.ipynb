# %% [markdown]
# # Student Alcohol Consumption

# %% [markdown]
# ### Step 1. Import the necessary libraries

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Step 2. Import the datasets *student-mat* and *student-por* and merge them.

# %%
student_mat = pd.read_csv('student-mat.csv', sep = ',')
student_por = pd.read_csv('student-por.csv', sep = ',')

# %%
student_mat.head(2)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences G1 G2 G3
# 0      4        3      4     1     1      3        6  5  6  6
# 1      5        3      3     1     1      3        4  5  5  6
#
# [2 rows x 33 columns]

# %%
student_por.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 644  ...      5        4      2     1     2      5        4  10  11  10
# 645  ...      4        3      4     1     1      1        4  15  15  16
# 646  ...      1        1      1     1     1      5        6  11  12   9
# 647  ...      2        4      5     3     4      2        6  10  10  10
# 648  ...      4        4      1     3     4      5        4  10  11  11
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Step 3. Assign it to a variable called df.

# %%
df = pd.concat([student_mat,student_por])

# %%
df.shape
# Out:
# (1044, 33)

# %% [markdown]
# ### Step 4. For the purpose of this exercise slice the dataframe from 'school' until the 'guardian' column

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
sliced_data = df.loc[:,['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
       'Mjob', 'Fjob', 'reason', 'guardian']]

# %%
sliced_data.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher
# 1     GP   F   17       U     GT3       T     1     1  at_home     other
# 2     GP   F   15       U     LE3       T     1     1  at_home     other
# 3     GP   F   15       U     GT3       T     4     2   health  services
# 4     GP   F   16       U     GT3       T     3     3    other     other
#
#    reason guardian
# 0  course   mother
# 1  course   father
# 2   other   mother
# 3    home   mother
# 4    home   father

# %% [markdown]
# ### Step 5. Create a lambda function that captalize strings.

# %%
capitalize = lambda x:x.capitalize()

# %% [markdown]
# ### Step 6. Capitalize both Mjob and Fjob

# %%
df.Mjob.apply(capitalize)
df.Fjob.apply(capitalize)
# Out:
# 0       Teacher
# 1         Other
# 2         Other
# 3      Services
# 4         Other
#          ...
# 644       Other
# 645    Services
# 646       Other
# 647    Services
# 648       Other
# Name: Fjob, Length: 1044, dtype: object

# %%
df.Mjob.str.capitalize().head()
# Out:
# 0    At_home
# 1    At_home
# 2    At_home
# 3     Health
# 4      Other
# Name: Mjob, dtype: object

# %%
df.Fjob.apply(capitalize).head()
# Out:
# 0     Teacher
# 1       Other
# 2       Other
# 3    Services
# 4       Other
# Name: Fjob, dtype: object

# %% [markdown]
# ### Step 7. Print the last elements of the data set.

# %%
df.tail()
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
#      ... freetime goout  Dalc  Walc  health absences  G1  G2  G3 legal_drinker
# 644  ...        4     2     1     2       5        4  10  11  10          True
# 645  ...        3     4     1     1       1        4  15  15  16          True
# 646  ...        1     1     1     1       5        6  11  12   9          True
# 647  ...        4     5     3     4       2        6  10  10  10         False
# 648  ...        4     1     3     4       5        4  10  11  11          True
#
# [5 rows x 34 columns]

# %% [markdown]
# ### Step 8. Did you notice the original dataframe is still lowercase? Why is that? Fix it and captalize Mjob and Fjob.

# %%
df['Mjob'].apply(lambda x:x.capitalize())
# Out:
# 0       At_home
# 1       At_home
# 2       At_home
# 3        Health
# 4         Other
#          ...
# 644    Services
# 645     Teacher
# 646       Other
# 647    Services
# 648    Services
# Name: Mjob, Length: 1044, dtype: object

# %%
df['Fjob'].apply(lambda x:x.capitalize())
# Out:
# 0       Teacher
# 1         Other
# 2         Other
# 3      Services
# 4         Other
#          ...
# 644       Other
# 645    Services
# 646       Other
# 647    Services
# 648       Other
# Name: Fjob, Length: 1044, dtype: object

# %% [markdown]
# ### Step 9. Create a function called majority that return a boolean value to a new column called legal_drinker

# %%
def majority(n):
    
    if n >= 18:
        return True
    else:
        return False

# %%
df['legal_drinker'] = df.age.apply(majority)

# %%
df.head(3)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob     Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home  teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home    other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home    other  ...
#
#   freetime goout  Dalc  Walc  health absences G1 G2  G3 legal_drinker
# 0        3     4     1     1       3        6  5  6   6          True
# 1        3     3     1     1       3        4  5  5   6         False
# 2        3     2     2     3       3       10  7  8  10         False
#
# [3 rows x 34 columns]

# %% [markdown]
# ### Step 10. Multiply every number of the dataset by 10.

# %%
df.select_dtypes(include=['number'])*10
# Out:
#      age  Medu  Fedu  traveltime  studytime  failures  famrel  freetime  \
# 0    180    40    40          20         20         0      40        30
# 1    170    10    10          10         20         0      50        30
# 2    150    10    10          10         20        30      40        30
# 3    150    40    20          10         30         0      30        20
# 4    160    30    30          10         20         0      40        30
# ..   ...   ...   ...         ...        ...       ...     ...       ...
# 644  190    20    30          10         30        10      50        40
# 645  180    30    10          10         20         0      40        30
# 646  180    10    10          20         20         0      10        10
# 647  170    30    10          20         10         0      20        40
# 648  180    30    20          30         10         0      40        40
#
#      goout  Dalc  Walc  health  absences   G1   G2   G3
# ...
